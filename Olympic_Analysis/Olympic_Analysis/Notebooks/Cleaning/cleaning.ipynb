# %%
# Import dependencies
from pymongo import MongoClient
from password import connection_string
import pandas as pd
import numpy as np

# %% [markdown]
# ## Working with MongoDB

# %%
# connect to MongoDB
myclient = MongoClient(connection_string)

# database
db = myclient['Olympics_Machine_Learning_Project_Data']

# %%
# Hosts collection
hosts_collection = db["hosts"]

# Take data off of MongoDB
hosts_df = pd.DataFrame(list(hosts_collection.find()))

# %%
# GDP collection
gdp_collection = db["gdp"]

# Take data off of MongoDB
gdp_df = pd.DataFrame(list(gdp_collection.find()))

# %%
# Population collection
population_collection = db["population"]

# Take data off of MongoDB
population_df = pd.DataFrame(list(population_collection.find()))

# %%
# Coordinates collection
coordinates_collection = db["coordinates"]

# Take data off of MongoDB
coordinates_df = pd.DataFrame(list(coordinates_collection.find()))

# %%
# NOC regions collection
noc_regions_collection = db["noc_regions"]

# Take data off of MongoDB
noc_regions_df = pd.DataFrame(list(noc_regions_collection.find()))

# %%
# Athlete events collection
athlete_events_collection = db["athlete_events"]

# Take data off of MongoDB
athlete_events_df = pd.DataFrame(list(athlete_events_collection.find()))

# %% [markdown]
# ## Cleaning and Merging the Data

# %%
# Return first 5 rows of athlete_events_df
athlete_events_df.head()
# Out:
#                         _id  ID                  Name Sex   Age  Height  \
# 0  6094127943a40af1a4be5bbd  15  Arvo Ossian Aaltonen   M  22.0     NaN
# 1  6094127943a40af1a4be5ba7   6       Per Knut Aaland   M  31.0   188.0
# 2  6094127943a40af1a4be5bd9  20    Kjetil Andr Aamodt   M  22.0   176.0
# 3  6094127943a40af1a4be5bee  24      Nils Egil Aaness   M  24.0     NaN
# 4  6094127943a40af1a4be5bfe  36  Stefan Remco Aartsen   M  21.0   194.0
#
#    Weight           Team  NOC        Games  Year  Season          City  \
# 0     NaN        Finland  FIN  1912 Summer  1912  Summer     Stockholm
# 1    75.0  United States  USA  1992 Winter  1992  Winter   Albertville
# 2    85.0         Norway  NOR  1994 Winter  1994  Winter   Lillehammer
# 3     NaN         Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 4    78.0    Netherlands  NED  1996 Summer  1996  Summer       Atlanta
#
#                   Sport                                              Event  \
# 0              Swimming             Swimming Men's 200 metres Breaststroke
# 1  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 2         Alpine Skiing                       Alpine Skiing Men's Downhill
# 3         Speed Skating                   Speed Skating Men's 1,500 metres
# 4              Swimming                Swimming Men's 100 metres Butterfly
#
#     Medal
# 0     NaN
# 1     NaN
# 2  Silver
# 3     NaN
# 4     NaN

# %%
# Return first 5 rows of noc_regions_df
noc_regions_df.head()
# Out:
#                         _id  NOC                            region  \
# 0  6094127543a40af1a4be5acc  BOL                           Bolivia
# 1  6094127543a40af1a4be5add  CHN                             China
# 2  6094127543a40af1a4be5aea  COD  Democratic Republic of the Congo
# 3  6094127543a40af1a4be5aee  DOM                Dominican Republic
# 4  6094127543a40af1a4be5b0e  IOA       Individual Olympic Athletes
#
#                          notes
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4  Individual Olympic Athletes

# %%
# Merge the athlete_events_df with the noc_regions_df
olympic_data_df = athlete_events_df.merge(noc_regions_df, left_on = 'NOC', right_on = 'NOC', how = 'left')

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#                       _id_x  ID                  Name Sex   Age  Height  \
# 0  6094127943a40af1a4be5bbd  15  Arvo Ossian Aaltonen   M  22.0     NaN
# 1  6094127943a40af1a4be5ba7   6       Per Knut Aaland   M  31.0   188.0
# 2  6094127943a40af1a4be5bd9  20    Kjetil Andr Aamodt   M  22.0   176.0
# 3  6094127943a40af1a4be5bee  24      Nils Egil Aaness   M  24.0     NaN
# 4  6094127943a40af1a4be5bfe  36  Stefan Remco Aartsen   M  21.0   194.0
#
#    Weight           Team  NOC        Games  Year  Season          City  \
# 0     NaN        Finland  FIN  1912 Summer  1912  Summer     Stockholm
# 1    75.0  United States  USA  1992 Winter  1992  Winter   Albertville
# 2    85.0         Norway  NOR  1994 Winter  1994  Winter   Lillehammer
# 3     NaN         Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 4    78.0    Netherlands  NED  1996 Summer  1996  Summer       Atlanta
#
#                   Sport                                              Event  \
# 0              Swimming             Swimming Men's 200 metres Breaststroke
# 1  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 2         Alpine Skiing                       Alpine Skiing Men's Downhill
# 3         Speed Skating                   Speed Skating Men's 1,500 metres
# 4              Swimming                Swimming Men's 100 metres Butterfly
#
#     Medal                     _id_y       region notes
# 0     NaN  6094127543a40af1a4be5af7      Finland   NaN
# 1     NaN  6094127543a40af1a4be5b8c          USA   NaN
# 2  Silver  6094127543a40af1a4be5b49       Norway   NaN
# 3     NaN  6094127543a40af1a4be5b49       Norway   NaN
# 4     NaN  6094127543a40af1a4be5b43  Netherlands   NaN

# %%
# Check for 'NaN'
olympic_data_df.isna().sum()
# Out:
# _id_x          0
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# _id_y        349
# region       370
# notes     266077
# dtype: int64

# %%
# Showing rows where 'region is 'NaN'
olympic_data_df.loc[olympic_data_df['region'].isnull(),['NOC', 'Team']].drop_duplicates()
# Out:
#         NOC                      Team
# 506     SGP                 Singapore
# 6354    ROT  Refugee Olympic Athletes
# 44391   SGP              June Climene
# 61106   UNK                   Unknown
# 64269   TUV                    Tuvalu
# 82050   SGP                   Rika II
# 108281  SGP               Singapore-2
# 235299  SGP               Singapore-1

# %%
# "Manually" fixing the values above
olympic_data_df['region'] = np.where(olympic_data_df['NOC']=='SGP', 'Singapore', olympic_data_df['region'])
olympic_data_df['region'] = np.where(olympic_data_df['NOC']=='ROT', 'Refugee Olympic Athletes', olympic_data_df['region'])
olympic_data_df['region'] = np.where(olympic_data_df['NOC']=='TUV', 'Tuvalu', olympic_data_df['region'])
olympic_data_df['region'] = np.where(olympic_data_df['NOC']=='UNK', 'Unknown', olympic_data_df['region'])

# %%
# Check for 'NaN'
olympic_data_df.isna().sum()
# Out:
# _id_x          0
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# _id_y        349
# region         0
# notes     266077
# dtype: int64

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#                       _id_x  ID                  Name Sex   Age  Height  \
# 0  6094127943a40af1a4be5bbd  15  Arvo Ossian Aaltonen   M  22.0     NaN
# 1  6094127943a40af1a4be5ba7   6       Per Knut Aaland   M  31.0   188.0
# 2  6094127943a40af1a4be5bd9  20    Kjetil Andr Aamodt   M  22.0   176.0
# 3  6094127943a40af1a4be5bee  24      Nils Egil Aaness   M  24.0     NaN
# 4  6094127943a40af1a4be5bfe  36  Stefan Remco Aartsen   M  21.0   194.0
#
#    Weight           Team  NOC        Games  Year  Season          City  \
# 0     NaN        Finland  FIN  1912 Summer  1912  Summer     Stockholm
# 1    75.0  United States  USA  1992 Winter  1992  Winter   Albertville
# 2    85.0         Norway  NOR  1994 Winter  1994  Winter   Lillehammer
# 3     NaN         Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 4    78.0    Netherlands  NED  1996 Summer  1996  Summer       Atlanta
#
#                   Sport                                              Event  \
# 0              Swimming             Swimming Men's 200 metres Breaststroke
# 1  Cross Country Skiing  Cross Country Skiing Men's 4 x 10 kilometres R...
# 2         Alpine Skiing                       Alpine Skiing Men's Downhill
# 3         Speed Skating                   Speed Skating Men's 1,500 metres
# 4              Swimming                Swimming Men's 100 metres Butterfly
#
#     Medal                     _id_y       region notes
# 0     NaN  6094127543a40af1a4be5af7      Finland   NaN
# 1     NaN  6094127543a40af1a4be5b8c          USA   NaN
# 2  Silver  6094127543a40af1a4be5b49       Norway   NaN
# 3     NaN  6094127543a40af1a4be5b49       Norway   NaN
# 4     NaN  6094127543a40af1a4be5b43  Netherlands   NaN

# %%
# Dropping uneccessary columns
olympic_data_df.drop(['_id_x', 'Name', 'Age', 'Height', 'Weight', 'Team', 'NOC',
                         'Games', '_id_y', 'notes'], axis = 1, inplace = True)

# %%
# Change column names
olympic_data_df.rename(columns = {'region': 'Team', 'City': 'Host City'}, inplace = True)

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID Sex  Year  Season     Host City                 Sport  \
# 0  15   M  1912  Summer     Stockholm              Swimming
# 1   6   M  1992  Winter   Albertville  Cross Country Skiing
# 2  20   M  1994  Winter   Lillehammer         Alpine Skiing
# 3  24   M  1960  Winter  Squaw Valley         Speed Skating
# 4  36   M  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands

# %%
# Creating copies of the olympic_data_df to help get the discipline and event count per team
discipline_helper_df = olympic_data_df
event_helper_df = olympic_data_df

# %%
# Adding a column to each of the helper DataFrames that only contains ones
discipline_helper_df['discipline helper'] = 1
event_helper_df['event helper'] = 1

# %%
# Dropping duplicates so we can get a unique count
discipline_helper_df = discipline_helper_df.drop_duplicates(['Year', 'Season', 'Team', 'Sport'])

# %%
# Dropping duplicates so we can get a unique count
event_helper_df = event_helper_df.drop_duplicates(['Year', 'Season', 'Team', 'Event'])

# %%
# Getting a count of the unique disciplines per team
discipline_helper_df = discipline_helper_df.groupby(['Year', 'Season', 'Team'])[['discipline helper']]\
.agg('sum').reset_index()

# %%
# Getting a count of the unique events per team
event_helper_df = event_helper_df.groupby(['Year', 'Season', 'Team'])[['event helper']].agg('sum').reset_index()

# %%
# Merging the olympic_data_df with the discipline_helper_df
olympic_data_df = olympic_data_df.merge(discipline_helper_df, left_on = ['Year', 'Season', 'Team'], 
                                        right_on = ['Year', 'Season', 'Team'], how = 'left')

# %%
# Merging the olympic_data_df with the event_helper_df
olympic_data_df = olympic_data_df.merge(event_helper_df, left_on = ['Year', 'Season', 'Team'], 
                                        right_on = ['Year', 'Season', 'Team'], how = 'left')

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID Sex  Year  Season     Host City                 Sport  \
# 0  15   M  1912  Summer     Stockholm              Swimming
# 1   6   M  1992  Winter   Albertville  Cross Country Skiing
# 2  20   M  1994  Winter   Lillehammer         Alpine Skiing
# 3  24   M  1960  Winter  Squaw Valley         Speed Skating
# 4  36   M  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands
#
#    discipline helper_x  event helper_x  discipline helper_y  event helper_y
# 0                    1               1                   10              49
# 1                    1               1                   12              56
# 2                    1               1                   10              48
# 3                    1               1                    6              17
# 4                    1               1                   19              94

# %%
# Dropping the helper columns
olympic_data_df.drop(['discipline helper_x', 'event helper_x'], axis = 1, inplace = True)

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID Sex  Year  Season     Host City                 Sport  \
# 0  15   M  1912  Summer     Stockholm              Swimming
# 1   6   M  1992  Winter   Albertville  Cross Country Skiing
# 2  20   M  1994  Winter   Lillehammer         Alpine Skiing
# 3  24   M  1960  Winter  Squaw Valley         Speed Skating
# 4  36   M  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands
#
#    discipline helper_y  event helper_y
# 0                   10              49
# 1                   12              56
# 2                   10              48
# 3                    6              17
# 4                   19              94

# %%
# Renaming columns
olympic_data_df.rename(columns = {'discipline helper_y': 'Team Disciplines', 'event helper_y': 'Team Events'}, inplace = True)

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID Sex  Year  Season     Host City                 Sport  \
# 0  15   M  1912  Summer     Stockholm              Swimming
# 1   6   M  1992  Winter   Albertville  Cross Country Skiing
# 2  20   M  1994  Winter   Lillehammer         Alpine Skiing
# 3  24   M  1960  Winter  Squaw Valley         Speed Skating
# 4  36   M  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands
#
#    Team Disciplines  Team Events
# 0                10           49
# 1                12           56
# 2                10           48
# 3                 6           17
# 4                19           94

# %%
# Dropping duplicates and getting the gender count per team
gender_count = olympic_data_df.drop_duplicates(['Year', 'Team', 'ID', 'Season']).groupby(['Team', 'Year', 'Season', 'Sex']).size()

# %%
# Making gender_count a DataFrame
gender_count_df = pd.DataFrame(gender_count)

# %%
# Return first 5 rows of gender_count_df
gender_count_df.head()
# Out:
#                               0
# Team        Year Season Sex
# Afghanistan 1936 Summer M    15
#             1948 Summer M    25
#             1956 Summer M    12
#             1960 Summer M    12
#             1964 Summer M     8

# %%
# Merging the olympic_data_df with the gender_count_df
olympic_data_df = olympic_data_df.merge(gender_count_df, left_on = ['Team', 'Year', 'Season', 'Sex'], 
                                        right_on = ['Team', 'Year', 'Season', 'Sex'], how = 'left')

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID Sex  Year  Season     Host City                 Sport  \
# 0  15   M  1912  Summer     Stockholm              Swimming
# 1   6   M  1992  Winter   Albertville  Cross Country Skiing
# 2  20   M  1994  Winter   Lillehammer         Alpine Skiing
# 3  24   M  1960  Winter  Squaw Valley         Speed Skating
# 4  36   M  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands
#
#    Team Disciplines  Team Events    0
# 0                10           49  162
# 1                12           56   98
# 2                10           48   66
# 3                 6           17   25
# 4                19           94  137

# %%
# Renaming columns
olympic_data_df.rename(columns = {0: 'Gender Count'}, inplace = True)

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID Sex  Year  Season     Host City                 Sport  \
# 0  15   M  1912  Summer     Stockholm              Swimming
# 1   6   M  1992  Winter   Albertville  Cross Country Skiing
# 2  20   M  1994  Winter   Lillehammer         Alpine Skiing
# 3  24   M  1960  Winter  Squaw Valley         Speed Skating
# 4  36   M  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands
#
#    Team Disciplines  Team Events  Gender Count
# 0                10           49           162
# 1                12           56            98
# 2                10           48            66
# 3                 6           17            25
# 4                19           94           137

# %%
# Creating a helper DataFrame and dropping the duplicates
helper_df = olympic_data_df.drop_duplicates(['Sex', 'Team', 'Season', 'Year'])

# %%
# Pivoting the helper_df to add the gender columns
helper_df = helper_df.pivot(index=['Year', 'Season', 'Team'], columns='Sex', values='Gender Count')

# %%
# Return first 5 rows of helper_df
helper_df.head()
# Out:
# Sex                     F     M
# Year Season Team
# 1896 Summer Australia NaN   1.0
#             Austria   NaN   3.0
#             Denmark   NaN   3.0
#             France    NaN  12.0
#             Germany   NaN  19.0

# %%
# Merging the olympic_data_df with the helper_df
olympic_data_df = olympic_data_df.merge(helper_df, left_on = ['Team', 'Year', 'Season'], 
                                        right_on = ['Team', 'Year', 'Season'], how = 'left')

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID Sex  Year  Season     Host City                 Sport  \
# 0  15   M  1912  Summer     Stockholm              Swimming
# 1   6   M  1992  Winter   Albertville  Cross Country Skiing
# 2  20   M  1994  Winter   Lillehammer         Alpine Skiing
# 3  24   M  1960  Winter  Squaw Valley         Speed Skating
# 4  36   M  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands
#
#    Team Disciplines  Team Events  Gender Count      F      M
# 0                10           49           162    2.0  162.0
# 1                12           56            98   50.0   98.0
# 2                10           48            66   21.0   66.0
# 3                 6           17            25    4.0   25.0
# 4                19           94           137  102.0  137.0

# %%
# Dropping columns
olympic_data_df.drop(['Gender Count', 'Sex'], axis = 1, inplace = True)

# %%
# Renaming columns
olympic_data_df.rename(columns = {'F': 'Females', 'M': 'Males'}, inplace = True)

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     NaN      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     NaN       Norway
# 4                Swimming Men's 100 metres Butterfly     NaN  Netherlands
#
#    Team Disciplines  Team Events  Females  Males
# 0                10           49      2.0  162.0
# 1                12           56     50.0   98.0
# 2                10           48     21.0   66.0
# 3                 6           17      4.0   25.0
# 4                19           94    102.0  137.0

# %%
# Find unique values in the medal column
olympic_data_df["Medal"].unique()
# Out:
# array([nan, 'Silver', 'Gold', 'Bronze'], dtype=object)

# %%
# Replace rows with 'NaN' for medal with 'DNW' (Did not win). This way, these rows won't be dropped if use the 'dropna'
# function later. Even though those athletes didn't win a medal, the more data to train on, the better.
olympic_data_df['Medal'].fillna('DNW', inplace=True)

# %%
# Return first 5 rows of olympic_data_df
olympic_data_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males
# 0                10           49      2.0  162.0
# 1                12           56     50.0   98.0
# 2                10           48     21.0   66.0
# 3                 6           17      4.0   25.0
# 4                19           94    102.0  137.0

# %%
# Check for 'NaN'
olympic_data_df.isna().sum()
# Out:
# ID                      0
# Year                    0
# Season                  0
# Host City               0
# Sport                   0
# Event                   0
# Medal                   0
# Team                    0
# Team Disciplines        0
# Team Events             0
# Females             18861
# Males                  72
# dtype: int64

# %%
# Fill 'NaN' with zeros
olympic_data_df = olympic_data_df.fillna(0)

# %%
# Check for 'NaN'
olympic_data_df.isna().sum()
# Out:
# ID                  0
# Year                0
# Season              0
# Host City           0
# Sport               0
# Event               0
# Medal               0
# Team                0
# Team Disciplines    0
# Team Events         0
# Females             0
# Males               0
# dtype: int64

# %%
# Return first 5 rows of coordinates_df
coordinates_df.head()
# Out:
#                         _id country_code   latitude  longitude  \
# 0  6094127243a40af1a4be59e2           CI   7.539989  -5.547080
# 1  6094127243a40af1a4be59dc           IO  -6.343194  71.876519
# 2  6094127243a40af1a4be59e9           TD  15.454166  18.732207
# 3  6094127243a40af1a4be5a03           FK -51.796253 -59.523613
# 4  6094127243a40af1a4be5a0c           GM  13.443182 -15.310139
#
#                              country usa_state_code  usa_state_latitude  \
# 0                        Ivory Coast             SC           33.836081
# 1     British Indian Ocean Territory            NaN                 NaN
# 2                               Chad            NaN                 NaN
# 3  Falkland Islands [Islas Malvinas]            NaN                 NaN
# 4                             Gambia            NaN                 NaN
#
#    usa_state_longitude       usa_state
# 0           -81.163725  South Carolina
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN

# %%
# Dropping uneccessary columns
coordinates_df.drop(['usa_state_code', 'usa_state_latitude', 'usa_state_longitude', 'usa_state', '_id'], axis=1, inplace=True)

# %%
# Return first 5 rows of coordinates_df
coordinates_df.head()
# Out:
#   country_code   latitude  longitude                            country
# 0           CI   7.539989  -5.547080                        Ivory Coast
# 1           IO  -6.343194  71.876519     British Indian Ocean Territory
# 2           TD  15.454166  18.732207                               Chad
# 3           FK -51.796253 -59.523613  Falkland Islands [Islas Malvinas]
# 4           GM  13.443182 -15.310139                             Gambia

# %%
# Check for 'NaN'
coordinates_df.isna().sum()
# Out:
# country_code    2
# latitude        1
# longitude       1
# country         0
# dtype: int64

# %%
# Showing 'NaN' 'country_code'
coordinates_df.loc[coordinates_df['country_code'].isnull(),['latitude', 'longitude', 'country']].drop_duplicates()
# Out:
#      latitude  longitude      country
# 19    6.87700   31.30700  South Sudan
# 157 -22.95764   18.49041      Namibia

# %%
# Showing 'NaN' 'latitude' and 'longitude'
coordinates_df.loc[coordinates_df['latitude'].isnull(),['country_code', 'longitude', 'country']].drop_duplicates()
# Out:
#     country_code  longitude                      country
# 177           UM        NaN  U.S. Minor Outlying Islands

# %%
# Merging olympic and coordinate data
olympic_coordinate_df = olympic_data_df.merge(coordinates_df, left_on = 'Team', right_on = 'country', how = 'left')

# %%
# Return first 5 rows of olympic_coordinate_df
olympic_coordinate_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males country_code   latitude  \
# 0                10           49      2.0  162.0           FI  61.924110
# 1                12           56     50.0   98.0           US  37.090240
# 2                10           48     21.0   66.0           NO  60.472024
# 3                 6           17      4.0   25.0           NO  60.472024
# 4                19           94    102.0  137.0           NL  52.132633
#
#    longitude      country
# 0  25.748151      Finland
# 1 -95.712891          USA
# 2   8.468946       Norway
# 3   8.468946       Norway
# 4   5.291266  Netherlands

# %%
# Checking 'NaN' 'country' after the merge
olympic_coordinate_df.loc[olympic_coordinate_df['country'].isnull(),['Team']].drop_duplicates()
# Out:
#                               Team
# 2316   Individual Olympic Athletes
# 6354      Refugee Olympic Athletes
# 61106                      Unknown

# %%
# Dropping uneccessary columns
olympic_coordinate_df.drop(['country_code', 'country'], axis=1, inplace=True)

# %%
# Return first 5 rows of olympic_coordinate_df
olympic_coordinate_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males   latitude  longitude
# 0                10           49      2.0  162.0  61.924110  25.748151
# 1                12           56     50.0   98.0  37.090240 -95.712891
# 2                10           48     21.0   66.0  60.472024   8.468946
# 3                 6           17      4.0   25.0  60.472024   8.468946
# 4                19           94    102.0  137.0  52.132633   5.291266

# %%
# Return first 5 rows of hosts_df
hosts_df.head()
# Out:
#                         _id    Type  \
# 0  6094126943a40af1a4bd4d5e  Summer
# 1  6094126943a40af1a4bd4d63  Summer
# 2  6094126943a40af1a4bd4d6c  Summer
# 3  6094126943a40af1a4bd4d80  Winter
# 4  6094126943a40af1a4bd4d54  Summer
#
#                                            GamesUrl  Disciplines  \
# 0  https://www.olympic.org/melbourne-stockholm-1956           23
# 1             https://www.olympic.org/montreal-1976           27
# 2               https://www.olympic.org/london-2012           36
# 3          https://www.olympic.org/albertville-1992           12
# 4             https://www.olympic.org/st-louis-1904           19
#
#                                      DisciplinesList            Country  \
# 0  ['Athletics', 'Basketball', 'Boxing', 'Canoe S...  Australia, Sweden
# 1  ['Archery', 'Athletics', 'Basketball', 'Boxing...             Canada
# 2  ['Archery', 'Athletics', 'Badminton', 'Basketb...                 UK
# 3  ['Alpine Skiing', 'Biathlon', 'Bobsleigh', 'Cr...             France
# 4  ['Archery', 'Athletics', 'Basketball', 'Boxing...                USA
#
#               Date  Athletes  Countries  Events                    City  Year  \
# 0  22 Nov - 08 Dec    3314.0       72.0   151.0  Melbourne - Stockholm   1956
# 1  17 Jul - 01 Aug    6084.0       92.0   198.0               Montreal   1976
# 2  27 Jul - 12 Aug   10568.0      204.0   302.0                 London   2012
# 3  08 Feb - 23 Feb    1801.0       64.0    57.0            Albertville   1992
# 4  01 Jul - 23 Nov     651.0       12.0    95.0               St Louis   1904
#
#    Host
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
# Dropping uneccessary columns
hosts_df.drop(['GamesUrl', 'Date', 'City', '_id', 'DisciplinesList'], axis=1, inplace=True)

# %%
# Return first 5 rows of hosts_df
hosts_df.head()
# Out:
#      Type  Disciplines            Country  Athletes  Countries  Events  Year  \
# 0  Summer           23  Australia, Sweden    3314.0       72.0   151.0  1956
# 1  Summer           27             Canada    6084.0       92.0   198.0  1976
# 2  Summer           36                 UK   10568.0      204.0   302.0  2012
# 3  Winter           12             France    1801.0       64.0    57.0  1992
# 4  Summer           19                USA     651.0       12.0    95.0  1904
#
#    Host
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
# Checking for 'NaN'. Those five are from years 2020 and beyond so we don't need to worry about them.
hosts_df.isna().sum()
# Out:
# Type           0
# Disciplines    0
# Country        0
# Athletes       5
# Countries      5
# Events         5
# Year           0
# Host           0
# dtype: int64

# %%
# Merging the olympic + coordinate data with certain columns of the host data
olympic_coordinate_host_df = olympic_coordinate_df.merge(hosts_df[['Host', 'Year', 'Type', 'Country']],
                                                         left_on = ['Year', 'Season', 'Team'], 
                                                         right_on = ['Year', 'Type', 'Country'], how = 'left')

# %%
# Return first 5 rows of olympic_coordinate_host_df
olympic_coordinate_host_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males   latitude  longitude  Host  \
# 0                10           49      2.0  162.0  61.924110  25.748151   NaN
# 1                12           56     50.0   98.0  37.090240 -95.712891   NaN
# 2                10           48     21.0   66.0  60.472024   8.468946   1.0
# 3                 6           17      4.0   25.0  60.472024   8.468946   NaN
# 4                19           94    102.0  137.0  52.132633   5.291266   NaN
#
#      Type Country
# 0     NaN     NaN
# 1     NaN     NaN
# 2  Winter  Norway
# 3     NaN     NaN
# 4     NaN     NaN

# %%
# Dropping uneccessary columns
olympic_coordinate_host_df.drop(['Type', 'Country'], axis=1, inplace=True)

# %%
# Merging the olympic + coordinate data with certain columns of the host data
olympic_coordinate_host_df = olympic_coordinate_host_df.merge(hosts_df[['Year', 'Type', 'Disciplines', 'Athletes', 'Countries', 'Events']],
                                                         left_on = ['Year', 'Season'], 
                                                         right_on = ['Year', 'Type'], how = 'left')

# %%
# Return first 5 rows of olympic_coordinate_host_df
olympic_coordinate_host_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males   latitude  longitude  Host  \
# 0                10           49      2.0  162.0  61.924110  25.748151   NaN
# 1                12           56     50.0   98.0  37.090240 -95.712891   NaN
# 2                10           48     21.0   66.0  60.472024   8.468946   1.0
# 3                 6           17      4.0   25.0  60.472024   8.468946   NaN
# 4                19           94    102.0  137.0  52.132633   5.291266   NaN
#
#      Type  Disciplines  Athletes  Countries  Events
# 0  Summer         18.0    2407.0       28.0   102.0
# 1  Winter         12.0    1801.0       64.0    57.0
# 2  Winter         12.0    1737.0       67.0    61.0
# 3  Winter          8.0     665.0       30.0    27.0
# 4  Summer         37.0   10318.0      197.0   271.0

# %%
# Dropping uneccessary columns
olympic_coordinate_host_df.drop(['Type'], axis=1, inplace=True)

# %%
# Replacing 'NaN' values in the host column with 0 (1 means host and 0 means not host)
values = {'Host':0}
olympic_coordinate_host_df = olympic_coordinate_host_df.fillna(value=values)

# %%
# Check for 'NaN' values
olympic_coordinate_host_df.isna().sum()
# Out:
# ID                     0
# Year                   0
# Season                 0
# Host City              0
# Sport                  0
# Event                  0
# Medal                  0
# Team                   0
# Team Disciplines       0
# Team Events            0
# Females                0
# Males                  0
# latitude             108
# longitude            108
# Host                   0
# Disciplines         1733
# Athletes            1733
# Countries           1733
# Events              1733
# dtype: int64

# %%
# Changing floats in the 'Host' column to int
olympic_coordinate_host_df['Host'] = olympic_coordinate_host_df['Host'].astype(int)

# %%
# Return first 5 rows of olympic_coordinate_host_df
olympic_coordinate_host_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males   latitude  longitude  Host  \
# 0                10           49      2.0  162.0  61.924110  25.748151     0
# 1                12           56     50.0   98.0  37.090240 -95.712891     0
# 2                10           48     21.0   66.0  60.472024   8.468946     1
# 3                 6           17      4.0   25.0  60.472024   8.468946     0
# 4                19           94    102.0  137.0  52.132633   5.291266     0
#
#    Disciplines  Athletes  Countries  Events
# 0         18.0    2407.0       28.0   102.0
# 1         12.0    1801.0       64.0    57.0
# 2         12.0    1737.0       67.0    61.0
# 3          8.0     665.0       30.0    27.0
# 4         37.0   10318.0      197.0   271.0

# %%
# Return first 5 rows of gdp_df
gdp_df.head()
# Out:
#                         _id  geo         name  time  Income per person  \
# 0  6094126c43a40af1a4bd4d98  afg  Afghanistan  1910               1277
# 1  6094126c43a40af1a4bd4d99  afg  Afghanistan  1911               1297
# 2  6094126c43a40af1a4bd4da6  afg  Afghanistan  1924               1599
# 3  6094126c43a40af1a4bd4dc5  afg  Afghanistan  1955               2579
# 4  6094126c43a40af1a4bd4de6  afg  Afghanistan  1988               2140
#
#      GDP total
# 0   7254447258
# 1   7751814270
# 2  14719115468
# 3  21330888368
# 4  24858545881

# %%
# Merging the olympic + coordinate + host data with the gdp data
olympic_coordinate_host_gdp_df = olympic_coordinate_host_df.merge(gdp_df, left_on = ['Year', 'Team'], 
                                                               right_on = ['time', 'name'], how = 'left')

# %%
# Return first 5 rows of olympic_coordinate_host_gdp_df
olympic_coordinate_host_gdp_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  ...  Disciplines  Athletes  Countries  \
# 0                10           49  ...         18.0    2407.0       28.0
# 1                12           56  ...         12.0    1801.0       64.0
# 2                10           48  ...         12.0    1737.0       67.0
# 3                 6           17  ...          8.0     665.0       30.0
# 4                19           94  ...         37.0   10318.0      197.0
#
#    Events                       _id  geo         name    time  \
# 0   102.0  6094126c43a40af1a4bd6e74  fin      Finland  1912.0
# 1    57.0  6094126c43a40af1a4bdb6b3  usa          USA  1992.0
# 2    61.0  6094126c43a40af1a4bd966c  nor       Norway  1994.0
# 3    27.0  6094126c43a40af1a4bd964a  nor       Norway  1960.0
# 4   271.0  6094126c43a40af1a4bd9399  nld  Netherlands  1996.0
#
#    Income per person     GDP total
# 0             3274.0  9.707610e+09
# 1            37045.0  9.520302e+12
# 2            48306.0  2.097252e+11
# 3            21705.0  7.775834e+10
# 4            36053.0  5.611086e+11
#
# [5 rows x 25 columns]

# %%
# Checking which 'name' rows contain 'NaN'
olympic_coordinate_host_gdp_df.loc[olympic_coordinate_host_gdp_df['name'].isnull(),
                                      ['Team']].drop_duplicates()
# Out:
#                               Team
# 581             Virgin Islands, US
# 1046                   Puerto Rico
# 1226                American Samoa
# 1508          Netherlands Antilles
# 2102                       Bermuda
# 2316   Individual Olympic Athletes
# 4860                          Guam
# 5086       Virgin Islands, British
# 5111                Cayman Islands
# 6354      Refugee Olympic Athletes
# 13117                Liechtenstein
# 17311                 Cook Islands
# 22320                        Aruba
# 61106                      Unknown
# 81394                       Kosovo

# %%
# Dropping uneccessary columns
olympic_coordinate_host_gdp_df.drop(['geo', 'name', 'time', '_id', 'Income per person'], axis=1, inplace=True)

# %%
# Return first 5 rows of olympic_coordinate_host_gdp_df
olympic_coordinate_host_gdp_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males   latitude  longitude  Host  \
# 0                10           49      2.0  162.0  61.924110  25.748151     0
# 1                12           56     50.0   98.0  37.090240 -95.712891     0
# 2                10           48     21.0   66.0  60.472024   8.468946     1
# 3                 6           17      4.0   25.0  60.472024   8.468946     0
# 4                19           94    102.0  137.0  52.132633   5.291266     0
#
#    Disciplines  Athletes  Countries  Events     GDP total
# 0         18.0    2407.0       28.0   102.0  9.707610e+09
# 1         12.0    1801.0       64.0    57.0  9.520302e+12
# 2         12.0    1737.0       67.0    61.0  2.097252e+11
# 3          8.0     665.0       30.0    27.0  7.775834e+10
# 4         37.0   10318.0      197.0   271.0  5.611086e+11

# %%
# Return first 5 rows of population_df
population_df.head()
# Out:
#                         _id  geo         name  time  Population
# 0  6094126f43a40af1a4bdbbfd  afg  Afghanistan  1896     4714779
# 1  6094126f43a40af1a4bdbc02  afg  Afghanistan  1901     4879685
# 2  6094126f43a40af1a4bdbc08  afg  Afghanistan  1907     5262120
# 3  6094126f43a40af1a4bdbc16  afg  Afghanistan  1921    10531818
# 4  6094126f43a40af1a4bdbc33  afg  Afghanistan  1950     7752117

# %%
# Merging the olympic + coordinate + host + gdp data with the population data
olympic_coordinate_host_gdp_pop_df = olympic_coordinate_host_gdp_df.merge(population_df, left_on = ['Year', 'Team'], 
                                                               right_on = ['time', 'name'], how = 'left')

# %%
# Return first 5 rows of olympic_coordinate_host_gdp_pop_df
olympic_coordinate_host_gdp_pop_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  ...  Disciplines  Athletes  Countries  \
# 0                10           49  ...         18.0    2407.0       28.0
# 1                12           56  ...         12.0    1801.0       64.0
# 2                10           48  ...         12.0    1737.0       67.0
# 3                 6           17  ...          8.0     665.0       30.0
# 4                19           94  ...         37.0   10318.0      197.0
#
#    Events     GDP total                       _id  geo         name    time  \
# 0   102.0  9.707610e+09  6094126f43a40af1a4bdea7f  fin      Finland  1912.0
# 1    57.0  9.520302e+12  6094126f43a40af1a4be521c  usa          USA  1992.0
# 2    61.0  2.097252e+11  6094126f43a40af1a4be2479  nor       Norway  1994.0
# 3    27.0  7.775834e+10  6094126f43a40af1a4be2457  nor       Norway  1960.0
# 4   271.0  5.611086e+11  6094126f43a40af1a4be207a  nld  Netherlands  1996.0
#
#     Population
# 0    2965061.0
# 1  256990608.0
# 2    4341616.0
# 3    3582508.0
# 4   15563252.0
#
# [5 rows x 25 columns]

# %%
# Checking which 'name' rows contain 'NaN'
olympic_coordinate_host_gdp_pop_df.loc[olympic_coordinate_host_gdp_pop_df['name'].isnull(),
                                      ['Team']].drop_duplicates()
# Out:
#                               Team
# 581             Virgin Islands, US
# 1046                   Puerto Rico
# 1226                American Samoa
# 1508          Netherlands Antilles
# 2102                       Bermuda
# 2316   Individual Olympic Athletes
# 4860                          Guam
# 5086       Virgin Islands, British
# 5111                Cayman Islands
# 6354      Refugee Olympic Athletes
# 17311                 Cook Islands
# 22320                        Aruba
# 61106                      Unknown
# 81394                       Kosovo

# %%
# Dropping uneccessary columns
olympic_coordinate_host_gdp_pop_df.drop(['geo', 'name', 'time', '_id'], axis=1, inplace=True)

# %%
# Return first 5 rows of olympic_coordinate_host_gdp_pop_df
olympic_coordinate_host_gdp_pop_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  ...  Males   latitude  longitude  Host  \
# 0                10           49  ...  162.0  61.924110  25.748151     0
# 1                12           56  ...   98.0  37.090240 -95.712891     0
# 2                10           48  ...   66.0  60.472024   8.468946     1
# 3                 6           17  ...   25.0  60.472024   8.468946     0
# 4                19           94  ...  137.0  52.132633   5.291266     0
#
#    Disciplines  Athletes  Countries  Events     GDP total   Population
# 0         18.0    2407.0       28.0   102.0  9.707610e+09    2965061.0
# 1         12.0    1801.0       64.0    57.0  9.520302e+12  256990608.0
# 2         12.0    1737.0       67.0    61.0  2.097252e+11    4341616.0
# 3          8.0     665.0       30.0    27.0  7.775834e+10    3582508.0
# 4         37.0   10318.0      197.0   271.0  5.611086e+11   15563252.0
#
# [5 rows x 21 columns]

# %%
# Creating the 'GDP per capita' column
olympic_coordinate_host_gdp_pop_df['GDP per capita'] = np.where(olympic_coordinate_host_gdp_pop_df['Population'] == np.nan, np.nan,
                    olympic_coordinate_host_gdp_pop_df['GDP total']
                    /olympic_coordinate_host_gdp_pop_df['Population'])

# %%
# Return first 5 rows of olympic_coordinate_host_gdp_pop_df
olympic_coordinate_host_gdp_pop_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  ...   latitude  longitude  Host  \
# 0                10           49  ...  61.924110  25.748151     0
# 1                12           56  ...  37.090240 -95.712891     0
# 2                10           48  ...  60.472024   8.468946     1
# 3                 6           17  ...  60.472024   8.468946     0
# 4                19           94  ...  52.132633   5.291266     0
#
#    Disciplines  Athletes  Countries  Events     GDP total   Population  \
# 0         18.0    2407.0       28.0   102.0  9.707610e+09    2965061.0
# 1         12.0    1801.0       64.0    57.0  9.520302e+12  256990608.0
# 2         12.0    1737.0       67.0    61.0  2.097252e+11    4341616.0
# 3          8.0     665.0       30.0    27.0  7.775834e+10    3582508.0
# 4         37.0   10318.0      197.0   271.0  5.611086e+11   15563252.0
#
#    GDP per capita
# 0     3274.000000
# 1    37045.330120
# 2    48305.780704
# 3    21705.000000
# 4    36053.428086
#
# [5 rows x 22 columns]

# %%
# Check for 'NaN' values
olympic_coordinate_host_gdp_pop_df.isna().sum()
# Out:
# ID                     0
# Year                   0
# Season                 0
# Host City              0
# Sport                  0
# Event                  0
# Medal                  0
# Team                   0
# Team Disciplines       0
# Team Events            0
# Females                0
# Males                  0
# latitude             108
# longitude            108
# Host                   0
# Disciplines         1733
# Athletes            1733
# Countries           1733
# Events              1733
# GDP total           2356
# Population          1987
# GDP per capita      2356
# dtype: int64

# %%
# Checking the length of olympic_coordinate_host_gdp_pop_df
len(olympic_coordinate_host_gdp_pop_df)
# Out:
# 271116

# %%
# Dropping duplicates from olympic_coordinate_host_gdp_pop_df and making a new DataFrame. We're not
# doing this to olympic_coordinate_host_gdp_pop_df because by dropping duplicate ID (an ID represents an athlete),
# we can no longer track athletes who won a medal in multiple events. However, we can now track the team size (just because
# an athlete competed in multiple events doesn't mean they count for more than 1 person in the team's size)
drop_duplicates_df = olympic_coordinate_host_gdp_pop_df.drop_duplicates(['Year', 'Team', 'ID', 'Season'])

# %%
# Creating a column of zeros called 'Team Size' in drop_duplicates_df
drop_duplicates_df['Team Size'] = 0
# Out:
# <ipython-input-100-5db2bcf73c9e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_duplicates_df['Team Size'] = 0

# %%
# Getting the fisrt 5 rows of drop_duplicates_df
drop_duplicates_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  ...  longitude  Host  Disciplines  Athletes  \
# 0                10           49  ...  25.748151     0         18.0    2407.0
# 1                12           56  ... -95.712891     0         12.0    1801.0
# 2                10           48  ...   8.468946     1         12.0    1737.0
# 3                 6           17  ...   8.468946     0          8.0     665.0
# 4                19           94  ...   5.291266     0         37.0   10318.0
#
#    Countries  Events     GDP total   Population  GDP per capita  Team Size
# 0       28.0   102.0  9.707610e+09    2965061.0     3274.000000          0
# 1       64.0    57.0  9.520302e+12  256990608.0    37045.330120          0
# 2       67.0    61.0  2.097252e+11    4341616.0    48305.780704          0
# 3       30.0    27.0  7.775834e+10    3582508.0    21705.000000          0
# 4      197.0   271.0  5.611086e+11   15563252.0    36053.428086          0
#
# [5 rows x 23 columns]

# %%
# Getting the size of each team using the groupby and count functions
size_by_team = drop_duplicates_df.groupby(['Year', 'Team', 'Season']).count()['Team Size']

# %%
# Checking the data type of size_by_team
size_by_team.dtype
# Out:
# dtype('int64')

# %%
# Making size_by_team a DataFrame
size_by_team_df = pd.DataFrame(size_by_team)

# %%
# Merging the olympic_coordinate_host_gdp_pop_df with the size_by_team_df
final_df = olympic_coordinate_host_gdp_pop_df.merge(size_by_team_df, left_on = ['Year', 'Team', 'Season'], 
                                                    right_on = ['Year', 'Team', 'Season'], how = 'left')

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#    ID  Year  Season     Host City                 Sport  \
# 0  15  1912  Summer     Stockholm              Swimming
# 1   6  1992  Winter   Albertville  Cross Country Skiing
# 2  20  1994  Winter   Lillehammer         Alpine Skiing
# 3  24  1960  Winter  Squaw Valley         Speed Skating
# 4  36  1996  Summer       Atlanta              Swimming
#
#                                                Event   Medal         Team  \
# 0             Swimming Men's 200 metres Breaststroke     DNW      Finland
# 1  Cross Country Skiing Men's 4 x 10 kilometres R...     DNW          USA
# 2                       Alpine Skiing Men's Downhill  Silver       Norway
# 3                   Speed Skating Men's 1,500 metres     DNW       Norway
# 4                Swimming Men's 100 metres Butterfly     DNW  Netherlands
#
#    Team Disciplines  Team Events  ...  longitude  Host  Disciplines  Athletes  \
# 0                10           49  ...  25.748151     0         18.0    2407.0
# 1                12           56  ... -95.712891     0         12.0    1801.0
# 2                10           48  ...   8.468946     1         12.0    1737.0
# 3                 6           17  ...   8.468946     0          8.0     665.0
# 4                19           94  ...   5.291266     0         37.0   10318.0
#
#    Countries  Events     GDP total   Population  GDP per capita  Team Size
# 0       28.0   102.0  9.707610e+09    2965061.0     3274.000000        164
# 1       64.0    57.0  9.520302e+12  256990608.0    37045.330120        148
# 2       67.0    61.0  2.097252e+11    4341616.0    48305.780704         87
# 3       30.0    27.0  7.775834e+10    3582508.0    21705.000000         29
# 4      197.0   271.0  5.611086e+11   15563252.0    36053.428086        239
#
# [5 rows x 23 columns]

# %%
# We no longer need the 'ID' clumn
final_df.drop('ID', axis=1, inplace=True)

# %%
# Drop duplicates to aovid things like adding 12 medals to a country that won basketball (one for each player)
# instead of just adding 1 (one for whole team)
final_df = final_df.drop_duplicates(['Year', 'Season', 'Event', 'Medal', 'Team'])

# %%
# We no longer need the 'Event' column
final_df.drop('Event', axis=1, inplace=True)

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#    Year  Season     Host City                 Sport   Medal         Team  \
# 0  1912  Summer     Stockholm              Swimming     DNW      Finland
# 1  1992  Winter   Albertville  Cross Country Skiing     DNW          USA
# 2  1994  Winter   Lillehammer         Alpine Skiing  Silver       Norway
# 3  1960  Winter  Squaw Valley         Speed Skating     DNW       Norway
# 4  1996  Summer       Atlanta              Swimming     DNW  Netherlands
#
#    Team Disciplines  Team Events  Females  Males  ...  longitude  Host  \
# 0                10           49      2.0  162.0  ...  25.748151     0
# 1                12           56     50.0   98.0  ... -95.712891     0
# 2                10           48     21.0   66.0  ...   8.468946     1
# 3                 6           17      4.0   25.0  ...   8.468946     0
# 4                19           94    102.0  137.0  ...   5.291266     0
#
#    Disciplines  Athletes  Countries  Events     GDP total   Population  \
# 0         18.0    2407.0       28.0   102.0  9.707610e+09    2965061.0
# 1         12.0    1801.0       64.0    57.0  9.520302e+12  256990608.0
# 2         12.0    1737.0       67.0    61.0  2.097252e+11    4341616.0
# 3          8.0     665.0       30.0    27.0  7.775834e+10    3582508.0
# 4         37.0   10318.0      197.0   271.0  5.611086e+11   15563252.0
#
#    GDP per capita  Team Size
# 0     3274.000000        164
# 1    37045.330120        148
# 2    48305.780704         87
# 3    21705.000000         29
# 4    36053.428086        239
#
# [5 rows x 21 columns]

# %%
# Summing medals by 'Medal', 'Year', 'Season', and 'Team'. Doing this in a new DataFrame because otherwise we will lose
# the other columns
final2_df = pd.DataFrame({'Medal Count' : final_df.groupby( ['Year', 'Season', 'Team', 'Medal'] ).size()}).reset_index()

# %%
# Getting the first 5 rows of final2_df
final2_df.head()
# Out:
#    Year  Season       Team   Medal  Medal Count
# 0  1896  Summer  Australia  Bronze            1
# 1  1896  Summer  Australia     DNW            2
# 2  1896  Summer  Australia    Gold            2
# 3  1896  Summer    Austria  Bronze            2
# 4  1896  Summer    Austria     DNW            3

# %%
# Dropping rows with 'DNW' so these aren't summed
final2_df = final2_df[final2_df.Medal != 'DNW']

# %%
# Getting the first 5 rows of final2_df
final2_df.head()
# Out:
#    Year  Season       Team   Medal  Medal Count
# 0  1896  Summer  Australia  Bronze            1
# 2  1896  Summer  Australia    Gold            2
# 3  1896  Summer    Austria  Bronze            2
# 5  1896  Summer    Austria    Gold            2
# 6  1896  Summer    Austria  Silver            1

# %%
# Merging final_df and final2_df to merge the medal totals
final_df = final_df.merge(final2_df, left_on = ['Year', 'Team', 'Season'], 
                                                right_on = ['Year', 'Team', 'Season'], how = 'left')

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#    Year  Season    Host City                 Sport Medal_x     Team  \
# 0  1912  Summer    Stockholm              Swimming     DNW  Finland
# 1  1912  Summer    Stockholm              Swimming     DNW  Finland
# 2  1912  Summer    Stockholm              Swimming     DNW  Finland
# 3  1992  Winter  Albertville  Cross Country Skiing     DNW      USA
# 4  1992  Winter  Albertville  Cross Country Skiing     DNW      USA
#
#    Team Disciplines  Team Events  Females  Males  ...  Disciplines  Athletes  \
# 0                10           49      2.0  162.0  ...         18.0    2407.0
# 1                10           49      2.0  162.0  ...         18.0    2407.0
# 2                10           49      2.0  162.0  ...         18.0    2407.0
# 3                12           56     50.0   98.0  ...         12.0    1801.0
# 4                12           56     50.0   98.0  ...         12.0    1801.0
#
#    Countries  Events     GDP total   Population  GDP per capita  Team Size  \
# 0       28.0   102.0  9.707610e+09    2965061.0      3274.00000        164
# 1       28.0   102.0  9.707610e+09    2965061.0      3274.00000        164
# 2       28.0   102.0  9.707610e+09    2965061.0      3274.00000        164
# 3       64.0    57.0  9.520302e+12  256990608.0     37045.33012        148
# 4       64.0    57.0  9.520302e+12  256990608.0     37045.33012        148
#
#    Medal_y  Medal Count
# 0   Bronze          9.0
# 1     Gold          9.0
# 2   Silver          8.0
# 3   Bronze          2.0
# 4     Gold          5.0
#
# [5 rows x 23 columns]

# %%
# Dropping uneccessary columns
final_df.drop(['Medal_x'], axis=1, inplace=True)

# %%
# Change column names
final_df.rename(columns = {'Medal_y': 'Medal Type'}, inplace = True)

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#    Year  Season    Host City                 Sport     Team  Team Disciplines  \
# 0  1912  Summer    Stockholm              Swimming  Finland                10
# 1  1912  Summer    Stockholm              Swimming  Finland                10
# 2  1912  Summer    Stockholm              Swimming  Finland                10
# 3  1992  Winter  Albertville  Cross Country Skiing      USA                12
# 4  1992  Winter  Albertville  Cross Country Skiing      USA                12
#
#    Team Events  Females  Males  latitude  ...  Disciplines  Athletes  \
# 0           49      2.0  162.0  61.92411  ...         18.0    2407.0
# 1           49      2.0  162.0  61.92411  ...         18.0    2407.0
# 2           49      2.0  162.0  61.92411  ...         18.0    2407.0
# 3           56     50.0   98.0  37.09024  ...         12.0    1801.0
# 4           56     50.0   98.0  37.09024  ...         12.0    1801.0
#
#    Countries  Events     GDP total   Population  GDP per capita  Team Size  \
# 0       28.0   102.0  9.707610e+09    2965061.0      3274.00000        164
# 1       28.0   102.0  9.707610e+09    2965061.0      3274.00000        164
# 2       28.0   102.0  9.707610e+09    2965061.0      3274.00000        164
# 3       64.0    57.0  9.520302e+12  256990608.0     37045.33012        148
# 4       64.0    57.0  9.520302e+12  256990608.0     37045.33012        148
#
#    Medal Type  Medal Count
# 0      Bronze          9.0
# 1        Gold          9.0
# 2      Silver          8.0
# 3      Bronze          2.0
# 4        Gold          5.0
#
# [5 rows x 22 columns]

# %%
# Have to drop duplicates for some reason. Will figure this out later to cut down on confusion and steps but for now
# this way is fine
final_df = final_df.drop_duplicates(['Year', 'Season', 'Medal Type', 'Team'])

# %%
# Creating a DataFrame that pivots the 'Medal Type' to columns
pivot_df = final_df.pivot(index=['Team', 'Year', 'Season'], columns='Medal Type', values='Medal Count')

# %%
# Getting the first 5 rows of pivot_df
pivot_df.head()
# Out:
# Medal Type               NaN  Bronze  Gold  Silver
# Team        Year Season
# Afghanistan 1936 Summer  NaN     NaN   NaN     NaN
#             1948 Summer  NaN     NaN   NaN     NaN
#             1956 Summer  NaN     NaN   NaN     NaN
#             1960 Summer  NaN     NaN   NaN     NaN
#             1964 Summer  NaN     NaN   NaN     NaN

# %%
# Filling 'NaN' with zeros
pivot_df = pivot_df.fillna(0)

# %%
# Making pivot_df a DataFrame
pivot_df = pd.DataFrame(pivot_df)

# %%
# Merging final_df with pivot_df
final_df = final_df.merge(pivot_df, left_on = ['Year', 'Team', 'Season'], 
                                                right_on = ['Year', 'Team', 'Season'], how = 'left')

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#    Year  Season    Host City                 Sport     Team  Team Disciplines  \
# 0  1912  Summer    Stockholm              Swimming  Finland                10
# 1  1912  Summer    Stockholm              Swimming  Finland                10
# 2  1912  Summer    Stockholm              Swimming  Finland                10
# 3  1992  Winter  Albertville  Cross Country Skiing      USA                12
# 4  1992  Winter  Albertville  Cross Country Skiing      USA                12
#
#    Team Events  Females  Males  latitude  ...     GDP total   Population  \
# 0           49      2.0  162.0  61.92411  ...  9.707610e+09    2965061.0
# 1           49      2.0  162.0  61.92411  ...  9.707610e+09    2965061.0
# 2           49      2.0  162.0  61.92411  ...  9.707610e+09    2965061.0
# 3           56     50.0   98.0  37.09024  ...  9.520302e+12  256990608.0
# 4           56     50.0   98.0  37.09024  ...  9.520302e+12  256990608.0
#
#    GDP per capita  Team Size  Medal Type  Medal Count  NaN  Bronze  Gold  \
# 0      3274.00000        164      Bronze          9.0  0.0     9.0   9.0
# 1      3274.00000        164        Gold          9.0  0.0     9.0   9.0
# 2      3274.00000        164      Silver          8.0  0.0     9.0   9.0
# 3     37045.33012        148      Bronze          2.0  0.0     2.0   5.0
# 4     37045.33012        148        Gold          5.0  0.0     2.0   5.0
#
#    Silver
# 0     8.0
# 1     8.0
# 2     8.0
# 3     4.0
# 4     4.0
#
# [5 rows x 26 columns]

# %%
# Dropping columns
final_df.drop(['Medal Type', 'Medal Count', np.nan], axis=1, inplace=True)

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#    Year  Season    Host City                 Sport     Team  Team Disciplines  \
# 0  1912  Summer    Stockholm              Swimming  Finland                10
# 1  1912  Summer    Stockholm              Swimming  Finland                10
# 2  1912  Summer    Stockholm              Swimming  Finland                10
# 3  1992  Winter  Albertville  Cross Country Skiing      USA                12
# 4  1992  Winter  Albertville  Cross Country Skiing      USA                12
#
#    Team Events  Females  Males  latitude  ...  Athletes  Countries  Events  \
# 0           49      2.0  162.0  61.92411  ...    2407.0       28.0   102.0
# 1           49      2.0  162.0  61.92411  ...    2407.0       28.0   102.0
# 2           49      2.0  162.0  61.92411  ...    2407.0       28.0   102.0
# 3           56     50.0   98.0  37.09024  ...    1801.0       64.0    57.0
# 4           56     50.0   98.0  37.09024  ...    1801.0       64.0    57.0
#
#       GDP total   Population  GDP per capita  Team Size  Bronze  Gold  Silver
# 0  9.707610e+09    2965061.0      3274.00000        164     9.0   9.0     8.0
# 1  9.707610e+09    2965061.0      3274.00000        164     9.0   9.0     8.0
# 2  9.707610e+09    2965061.0      3274.00000        164     9.0   9.0     8.0
# 3  9.520302e+12  256990608.0     37045.33012        148     2.0   5.0     4.0
# 4  9.520302e+12  256990608.0     37045.33012        148     2.0   5.0     4.0
#
# [5 rows x 23 columns]

# %%
# Dropping columns
final_df.drop(['Sport'], axis=1, inplace=True)

# %%
# Dropping duplicate rows
final_df = final_df.drop_duplicates(['Host City', 'Year', 'Team', 'Season', 'Females', 'Males', 'latitude',
                                     'longitude', 'Host', 'Disciplines', 'Athletes',
                                     'Countries', 'Events', 'GDP total',
                                     'Population', 'GDP per capita', 'Team Size', 'Bronze', 'Silver', 'Gold', 'Team Events',
                                    'Team Disciplines'])

# %%
# Change column names
final_df.rename(columns = {'latitude': 'Latitude', 'longitude': 'Longitude', 'GDP total': 'GDP Total',
                          'GDP per capita': 'GDP per Capita', 'Disciplines': 'Total Disciplines',
                          'Athletes': 'Total Athletes', 'Countries': 'Total Countries',
                           'Events': 'Total Events'}, inplace = True)

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#     Year  Season     Host City         Team  Team Disciplines  Team Events  \
# 0   1912  Summer     Stockholm      Finland                10           49
# 3   1992  Winter   Albertville          USA                12           56
# 6   1994  Winter   Lillehammer       Norway                10           48
# 9   1960  Winter  Squaw Valley       Norway                 6           17
# 11  1996  Summer       Atlanta  Netherlands                19           94
#
#     Females  Males   Latitude  Longitude  ...  Total Athletes  \
# 0       2.0  162.0  61.924110  25.748151  ...          2407.0
# 3      50.0   98.0  37.090240 -95.712891  ...          1801.0
# 6      21.0   66.0  60.472024   8.468946  ...          1737.0
# 9       4.0   25.0  60.472024   8.468946  ...           665.0
# 11    102.0  137.0  52.132633   5.291266  ...         10318.0
#
#     Total Countries  Total Events     GDP Total   Population  GDP per Capita  \
# 0              28.0         102.0  9.707610e+09    2965061.0     3274.000000
# 3              64.0          57.0  9.520302e+12  256990608.0    37045.330120
# 6              67.0          61.0  2.097252e+11    4341616.0    48305.780704
# 9              30.0          27.0  7.775834e+10    3582508.0    21705.000000
# 11            197.0         271.0  5.611086e+11   15563252.0    36053.428086
#
#     Team Size  Bronze  Gold  Silver
# 0         164     9.0   9.0     8.0
# 3         148     2.0   5.0     4.0
# 6          87     5.0   8.0    10.0
# 9          29     0.0   3.0     3.0
# 11        239    10.0   4.0     5.0
#
# [5 rows x 22 columns]

# %%
# Drop rows with 'NaN'
final_df = final_df.dropna()

# %%
# Creating a column that sums the three types of medals
final_df['Total Medals'] = final_df.iloc[:, 19:].sum(axis=1)

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#     Year  Season     Host City         Team  Team Disciplines  Team Events  \
# 0   1912  Summer     Stockholm      Finland                10           49
# 3   1992  Winter   Albertville          USA                12           56
# 6   1994  Winter   Lillehammer       Norway                10           48
# 9   1960  Winter  Squaw Valley       Norway                 6           17
# 11  1996  Summer       Atlanta  Netherlands                19           94
#
#     Females  Males   Latitude  Longitude  ...  Total Countries  Total Events  \
# 0       2.0  162.0  61.924110  25.748151  ...             28.0         102.0
# 3      50.0   98.0  37.090240 -95.712891  ...             64.0          57.0
# 6      21.0   66.0  60.472024   8.468946  ...             67.0          61.0
# 9       4.0   25.0  60.472024   8.468946  ...             30.0          27.0
# 11    102.0  137.0  52.132633   5.291266  ...            197.0         271.0
#
#        GDP Total   Population  GDP per Capita  Team Size  Bronze  Gold  \
# 0   9.707610e+09    2965061.0     3274.000000        164     9.0   9.0
# 3   9.520302e+12  256990608.0    37045.330120        148     2.0   5.0
# 6   2.097252e+11    4341616.0    48305.780704         87     5.0   8.0
# 9   7.775834e+10    3582508.0    21705.000000         29     0.0   3.0
# 11  5.611086e+11   15563252.0    36053.428086        239    10.0   4.0
#
#     Silver  Total Medals
# 0      8.0          26.0
# 3      4.0          11.0
# 6     10.0          23.0
# 9      3.0           6.0
# 11     5.0          19.0
#
# [5 rows x 23 columns]

# %%
# Make a column to represent the seasons as a number to help with machine learning
final_df['Season (Binary)'] = np.where(final_df.loc[:,'Season'] == 'Summer', 1, 0)

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#     Year  Season     Host City         Team  Team Disciplines  Team Events  \
# 0   1912  Summer     Stockholm      Finland                10           49
# 3   1992  Winter   Albertville          USA                12           56
# 6   1994  Winter   Lillehammer       Norway                10           48
# 9   1960  Winter  Squaw Valley       Norway                 6           17
# 11  1996  Summer       Atlanta  Netherlands                19           94
#
#     Females  Males   Latitude  Longitude  ...  Total Events     GDP Total  \
# 0       2.0  162.0  61.924110  25.748151  ...         102.0  9.707610e+09
# 3      50.0   98.0  37.090240 -95.712891  ...          57.0  9.520302e+12
# 6      21.0   66.0  60.472024   8.468946  ...          61.0  2.097252e+11
# 9       4.0   25.0  60.472024   8.468946  ...          27.0  7.775834e+10
# 11    102.0  137.0  52.132633   5.291266  ...         271.0  5.611086e+11
#
#      Population  GDP per Capita  Team Size  Bronze  Gold  Silver  \
# 0     2965061.0     3274.000000        164     9.0   9.0     8.0
# 3   256990608.0    37045.330120        148     2.0   5.0     4.0
# 6     4341616.0    48305.780704         87     5.0   8.0    10.0
# 9     3582508.0    21705.000000         29     0.0   3.0     3.0
# 11   15563252.0    36053.428086        239    10.0   4.0     5.0
#
#     Total Medals  Season (Binary)
# 0           26.0                1
# 3           11.0                0
# 6           23.0                0
# 9            6.0                0
# 11          19.0                1
#
# [5 rows x 24 columns]

# %%
# Check for 'NaN'
final_df.isna().sum()
# Out:
# Year                 0
# Season               0
# Host City            0
# Team                 0
# Team Disciplines     0
# Team Events          0
# Females              0
# Males                0
# Latitude             0
# Longitude            0
# Host                 0
# Total Disciplines    0
# Total Athletes       0
# Total Countries      0
# Total Events         0
# GDP Total            0
# Population           0
# GDP per Capita       0
# Team Size            0
# Bronze               0
# Gold                 0
# Silver               0
# Total Medals         0
# Season (Binary)      0
# dtype: int64

# %%
# Get the length of final_df
len(final_df)
# Out:
# 3606

# %%
# Changing order of the columns
final_df = final_df[['Host City', 'Year', 'Team', 'Season', 'Season (Binary)', 'Latitude', 'Longitude', 'Host', 'GDP Total',
                     'Population', 'Total Disciplines', 'Males', 'Females', 'Total Athletes', 'Total Events', 'Total Countries', 
                     'GDP per Capita', 'Team Disciplines', 'Team Events', 'Team Size', 'Bronze', 'Silver', 'Gold', 'Total Medals']]

# %%
# Getting the first 5 rows of final_df
final_df.head()
# Out:
#        Host City  Year         Team  Season  Season (Binary)   Latitude  \
# 0      Stockholm  1912      Finland  Summer                1  61.924110
# 3    Albertville  1992          USA  Winter                0  37.090240
# 6    Lillehammer  1994       Norway  Winter                0  60.472024
# 9   Squaw Valley  1960       Norway  Winter                0  60.472024
# 11       Atlanta  1996  Netherlands  Summer                1  52.132633
#
#     Longitude  Host     GDP Total   Population  ...  Total Events  \
# 0   25.748151     0  9.707610e+09    2965061.0  ...         102.0
# 3  -95.712891     0  9.520302e+12  256990608.0  ...          57.0
# 6    8.468946     1  2.097252e+11    4341616.0  ...          61.0
# 9    8.468946     0  7.775834e+10    3582508.0  ...          27.0
# 11   5.291266     0  5.611086e+11   15563252.0  ...         271.0
#
#     Total Countries  GDP per Capita  Team Disciplines  Team Events  Team Size  \
# 0              28.0     3274.000000                10           49        164
# 3              64.0    37045.330120                12           56        148
# 6              67.0    48305.780704                10           48         87
# 9              30.0    21705.000000                 6           17         29
# 11            197.0    36053.428086                19           94        239
#
#     Bronze  Silver  Gold  Total Medals
# 0      9.0     8.0   9.0          26.0
# 3      2.0     4.0   5.0          11.0
# 6      5.0    10.0   8.0          23.0
# 9      0.0     3.0   3.0           6.0
# 11    10.0     5.0   4.0          19.0
#
# [5 rows x 24 columns]

# %%
# # Export final_df to MS Excel - tableau_final.xlsx
# final_df.to_excel('tableau_final.xlsx')

# %%
# # change format of data
# data = final_df.to_dict('records')

# # Create a collection
# final_df_collection = db["final_df"]

# # add data to MongoDB
# final_df_collection.insert_many(data)

# %% [markdown]
# ## Visualization

# %%
# Import dependencies
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Plot to compare two continuous variables
sns.jointplot(x="Latitude", y="Total Medals", data=final_df)

# %%
# Dropping rows with 'Winter' for the season so these aren't included in the graph
summer_df = final_df[final_df.Season != 'Winter']

# %%
# Dropping rows with 'Summer' for the season so these aren't included in the graph
winter_df = final_df[final_df.Season != 'Summer']

# %%
# Plot to compare two continuous variables with the summer_df
sns.jointplot(x="Latitude", y="Total Medals", data=summer_df)

# %%
# Plot to compare two continuous variables with the winter_df
sns.jointplot(x="Latitude", y="Total Medals", data=winter_df)

# %%
# Representing correlations between various features in the summer_df as a heatmap
corrmat = summer_df[['Latitude', 'Longitude', 'Host', 'GDP Total', 'Males', 'Females', 'Team Events', 'Team Disciplines',
                     'Population', 'GDP per Capita',
                     'Team Size', 'Total Medals']].corr()
f, ax = plt.subplots(figsize=(10,10))
# annot controls annotations, square=True outputs squares as correlation representing figures, cmap represents color map
sns.heatmap(corrmat, vmax=.8, square=True, annot=True, fmt=".2f", cmap="summer")

# %%
# Representing correlations between various features in the winter_df as a heatmap
corrmat = winter_df[['Latitude', 'Longitude', 'Host', 'GDP Total', 'Males', 'Females', 'Team Events', 'Team Disciplines',
                     'Population', 'GDP per Capita',
                     'Team Size', 'Total Medals']].corr()
f, ax = plt.subplots(figsize=(10,10))
# annot controls annotations, square=True outputs squares as correlation representing figures, cmap represents color map
sns.heatmap(corrmat, vmax=.8, square=True, annot=True, fmt=".2f", cmap="winter")

# %%
# Plot to compare two continuous variables with the final_df
sns.jointplot(x="Team Size", y="Total Medals", data=final_df)

# %%
# Plot to compare two continuous variables with the final_df
sns.jointplot(x="GDP Total", y="Total Medals", data=final_df)

# %%
# Plot to compare two continuous variables with the final_df
sns.jointplot(x="GDP per Capita", y="Total Medals", data=final_df)

# %%
# Import dependency
from scipy.stats import linregress

# Create a function to create perform linear regression on the data
# and plot a regression line and the equation with the data
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation
#     plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Team Size')
    plt.ylabel(y_label)
    plt.show()

# %%
# Assigning values to the axis
x_values = final_df['Team Size']
y_values = final_df['Total Medals']

# Giving the graph a title
plt.title('Team Size versus Total Medals')

# Plotting the data
plot_linear_regression(x_values, y_values, 'Linear Regression for Team Size versus Total Medals', 'Total Medals', (5, 33))

# # Save the figure
# plt.savefig("Figures/teamsize_totalmedals.png")
